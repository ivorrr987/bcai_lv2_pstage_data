# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/opt/ml/data'

# %%
file_list = [file for file in sorted(os.listdir("./csv_data")) if file.endswith(".csv")]
file_list
# Out:
# ['가나 요리.csv',
#  '과테말라 요리.csv',
#  '그리스 요리.csv',
#  '나이지리아 요리.csv',
#  '남아프리카 공화국 요리.csv',
#  '네덜란드 요리.csv',
#  '네팔 요리.csv',
#  '노르웨이 요리.csv',
#  '니카라과 요리.csv',
#  '덴마크 요리.csv',
#  '독일 요리.csv',
#  '러시아 요리.csv',
#  '레바논 요리.csv',
#  '루마니아 요리.csv',
#  '마다가스카르 요리.csv',
#  '말레이시아 요리.csv',
#  '멕시코 요리.csv',
#  '모로코 요리.csv',
#  '몽골 요리.csv',
#  '미국 요리.csv',
#  '베트남 요리.csv',
#  '벨기에 요리.csv',
#  '브라질 요리.csv',
#  '세네갈 요리.csv',
#  '세르비아 요리.csv',
#  '소말리아 요리.csv',
#  '스웨덴 요리.csv',
#  '스페인 요리.csv',
#  '아르헨티나 요리.csv',
#  '아일랜드 요리.csv',
#  '알제리 요리.csv',
#  '에스토니아 요리.csv',
#  '에콰도르 요리.csv',
#  '에티오피아 요리.csv',
#  '엘살바도르 요리.csv',
#  '영국 요리.csv',
#  '오스트리아 요리.csv',
#  '온두라스 요리.csv',
#  '요리.csv',
#  '요리법.csv',
#  '우즈베키스탄 요리.csv',
#  '우크라이나 요리.csv',
#  '이라크 요리.csv',
#  '이집트 요리.csv',
#  '이탈리아 요리.csv',
#  '인도 요리.csv',
#  '인도네시아 요리.csv',
#  '일본 요리.csv',
#  '조리 (음식).csv',
#  '조리법.csv',
#  '중국 요리.csv',
#  '체코 요리.csv',
#  '칠레 요리.csv',
#  '카메룬 요리.csv',
#  '카자흐스탄 요리.csv',
#  '캐나다 요리.csv',
#  '코스타리카 요리.csv',
# ...

# %%
ghana = pd.read_csv(f"csv_data/{file_list[0]}")
ghana
# Out:
#     Unnamed: 0                                           sentence  subject  \
# 0            0             가나 요리(Ghana 料理, )는 서아프리카에 있는 가나의 요리이다.      NaN
# 1            1  다양한 종족과 민족이 거주하기 때문에 동서남북에 따라 음식의 형태나 관념이 많이 다르다.      NaN
# 2            2    대개 쌀과 푸푸, 투오, 기기, 이튜, 아토 등으로 구성되며 대개는 소스와 수프이다.      NaN
# 3            3                    수프에는 달팽이, 생선, 고기, 버섯 등을 넣어 먹는다.      NaN
# 4            4                                  자주 먹는 음식은 다음과 같다.      NaN
# 5            5                  대부분의 가나 음식은 한국식으로 하면 국이 꼭 따라 나온다.      NaN
# 6            6                                대개는 고기류와 토마토가 들어간다.      NaN
# 7            7  대개는 땅콩이나 야자열매 등을 조금씩 떼다가 국물용으로 사용하는데 켄키나 반푸의 경...      NaN
# 8            8  또 다른 대중적인 음식은 켈레웰레로서 밥과 국물을 먹는데 가끔씩은 그냥 후식으로 먹는다.      NaN
# 9            9  콘토미레라는 음식은 타로토란으로 요리하며 참치나 호박씨를 야자기름과 함께 볶아서 내...      NaN
# 10          10                       가나 음식은 대개 생선류나 곡류가 고루고루 나온다.      NaN
# ...

# %%
mor = pd.read_csv(f"csv_data/모로코 요리.csv")
mor
# Out:
#     Unnamed: 0                                           sentence  \
# 0            0  모로코 요리(Morocco 料理, )는 북아프리카 마그레브 지역에 있는 모로코의 요...
# 1            0  모로코 요리(Morocco 料理, )는 북아프리카 마그레브 지역에 있는 모로코의 요...
# 2            1                            세계에서도 가장 다채로운 요리로 손꼽힌다.
# 3            2  이는 모로코라는 국가 자체가 이슬람계를 비롯해 베르베르인, 무어인, 지중해 국가 출...
# 4            3  예로부터 왕실에서 전해지던 왕실 요리를 비롯해 수많은 민족의 요리가 지금의 모로코 ...
# 5            4   수많은 문명이 머물러 가는 기착지로 여겨졌던 모로코는 이 때문에 수많은 영향을 받았다.
# 6            5  베르베르인이 옛날부터 거주했으므로 그들의 음식이 뿌리를 두었다면 그 뿌리는 다양하게...
# 7            5  베르베르인이 옛날부터 거주했으므로 그들의 음식이 뿌리를 두었다면 그 뿌리는 다양하게...
# 8            5  베르베르인이 옛날부터 거주했으므로 그들의 음식이 뿌리를 두었다면 그 뿌리는 다양하게...
# 9            5  베르베르인이 옛날부터 거주했으므로 그들의 음식이 뿌리를 두었다면 그 뿌리는 다양하게...
# 10           6                          뿐만 아니라 유태인계 요리도 다수 남아 있다.
# 11           7  중세 피난민들은 바그다드를 떠나 모로코에 정착했고 그들의 요리법은 다시 모로코에 적...
# 12           7  중세 피난민들은 바그다드를 떠나 모로코에 정착했고 그들의 요리법은 다시 모로코에 적...
# ...

# %%
new = pd.concat([ghana, mor])
new
# Out:
#     Unnamed: 0                                           sentence   subject  \
# 0            0             가나 요리(Ghana 料理, )는 서아프리카에 있는 가나의 요리이다.       NaN
# 1            1  다양한 종족과 민족이 거주하기 때문에 동서남북에 따라 음식의 형태나 관념이 많이 다르다.       NaN
# 2            2    대개 쌀과 푸푸, 투오, 기기, 이튜, 아토 등으로 구성되며 대개는 소스와 수프이다.       NaN
# 3            3                    수프에는 달팽이, 생선, 고기, 버섯 등을 넣어 먹는다.       NaN
# 4            4                                  자주 먹는 음식은 다음과 같다.       NaN
# ..         ...                                                ...       ...
# 51          41  보카디요는 스페인식 샌드위치로서 지역마다 넣는 재료가 다르지만 대체적으로는 바게트 ...      보카디요
# 52          42                               낙농품은 모든 곳에서 구할 수 있다.      모든 곳
# 53          43  이러한 가게를 "mahlabas"라고 부르는데 모든 유제품을 구할 수 있으며 일종의...  mahlabas
# 54          44  쿠스쿠스는 북아프리카를 대표하는 요리로서 비단 모로코 뿐 아니라 다른 나라에서도 여...     북아프리카
# 55          45  유럽의 여러 레스토랑이나 작은 가게에서도 쿠스쿠스를 많이 볼 수 있는데 특히 프랑스...   모로코식 요리
#
#    object  label memo
# 0     NaN    NaN  NaN
# ...

# %%
new2 = pd.concat([ghana, mor], ignore_index=True)
new2
# Out:
#     Unnamed: 0                                           sentence   subject  \
# 0            0             가나 요리(Ghana 料理, )는 서아프리카에 있는 가나의 요리이다.       NaN
# 1            1  다양한 종족과 민족이 거주하기 때문에 동서남북에 따라 음식의 형태나 관념이 많이 다르다.       NaN
# 2            2    대개 쌀과 푸푸, 투오, 기기, 이튜, 아토 등으로 구성되며 대개는 소스와 수프이다.       NaN
# 3            3                    수프에는 달팽이, 생선, 고기, 버섯 등을 넣어 먹는다.       NaN
# 4            4                                  자주 먹는 음식은 다음과 같다.       NaN
# ..         ...                                                ...       ...
# 67          41  보카디요는 스페인식 샌드위치로서 지역마다 넣는 재료가 다르지만 대체적으로는 바게트 ...      보카디요
# 68          42                               낙농품은 모든 곳에서 구할 수 있다.      모든 곳
# 69          43  이러한 가게를 "mahlabas"라고 부르는데 모든 유제품을 구할 수 있으며 일종의...  mahlabas
# 70          44  쿠스쿠스는 북아프리카를 대표하는 요리로서 비단 모로코 뿐 아니라 다른 나라에서도 여...     북아프리카
# 71          45  유럽의 여러 레스토랑이나 작은 가게에서도 쿠스쿠스를 많이 볼 수 있는데 특히 프랑스...   모로코식 요리
#
#    object  label memo
# 0     NaN    NaN  NaN
# ...

# %%
temp = pd.DataFrame([])
temp2 = pd.concat([temp, ghana])
ghana == temp2
# Out:
#     Unnamed: 0  sentence  subject  object  label   memo
# 0         True      True    False   False  False  False
# 1         True      True    False   False  False  False
# 2         True      True    False   False  False  False
# 3         True      True    False   False  False  False
# 4         True      True    False   False  False  False
# 5         True      True    False   False  False  False
# 6         True      True    False   False  False  False
# 7         True      True    False   False  False  False
# 8         True      True    False   False  False  False
# 9         True      True    False   False  False  False
# 10        True      True    False   False  False  False
# 11        True      True    False   False  False  False
# 12        True      True    False   False  False  False
# 13        True      True    False   False  False  False
# 14        True      True    False   False  False  False
# 15        True      True    False   False  False  False

# %%
total = pd.DataFrame([])
for file in file_list:
    temp = pd.read_csv(f"./csv_data/{file}")
    total = pd.concat([total, temp], ignore_index=True)
total
# Out:
#       Unnamed: 0                                           sentence subject  \
# 0              0             가나 요리(Ghana 料理, )는 서아프리카에 있는 가나의 요리이다.     NaN
# 1              1  다양한 종족과 민족이 거주하기 때문에 동서남북에 따라 음식의 형태나 관념이 많이 다르다.     NaN
# 2              2    대개 쌀과 푸푸, 투오, 기기, 이튜, 아토 등으로 구성되며 대개는 소스와 수프이다.     NaN
# 3              3                    수프에는 달팽이, 생선, 고기, 버섯 등을 넣어 먹는다.     NaN
# 4              4                                  자주 먹는 음식은 다음과 같다.     NaN
# ...          ...                                                ...     ...
# 2629          43                       호텔 안의 프랑스 요리점은 프랑스 찬팅이라고 한다.     NaN
# 2630          44       맛도 좋고 실내 장식과 서비스도 세련되었으며 가격도 그리 비싸지 않은 가게이다.     NaN
# 2631          45              마이땅라오(맥도널드)나 KFC는 맛과 시스템이 대한민국과 비슷하다.     NaN
# 2632          46                            땨쟈러(大家樂)는 홍콩 자본의 체인점이다.     NaN
# 2633          47  면류나 덮밥 등의 중화 메뉴도 있는 패스트푸드점인 小食店은 오전5시부터 밤12시까지...     NaN
#
#      object  label memo
# 0       NaN    NaN  NaN
# ...

# %%
cnt = 0
for file in file_list:
    temp = pd.read_csv(f"csv_data/{file}")
    print(len(temp))
    cnt += len(temp)
print(cnt)
# Out:
# 16
# 13
# 29
# 5
# 22
# 61
# 5
# 50
# 14
# 14
# 59
# 126
# 13
# 20
# 32
# 18
# 34
# 55
# 76
# 15
# 22
# 17
# 74
# 15
# 30
# 53
# 8
# 49
# 7
# 37
# 9
# 27
# 7
# 33
# 20
# 30
# 20
# 27
# 10
# 4
# 3
# 42
# 8
# 12
# 340
# 40
# 30
# 38
# 4
# 33
# 74
# 27
# 15
# 16
# 16
# 25
# 24
# 15
# 29
# 9
# 43
# 128
# 12
# 36
# 47
# 26
# 17
# 6
# 173
# 25
# 97
# 48
# 2634

# %%
total.to_csv("total.csv")

# %%
total
# Out:
#       Unnamed: 0                                           sentence subject  \
# 0              0             가나 요리(Ghana 料理, )는 서아프리카에 있는 가나의 요리이다.     NaN
# 1              1  다양한 종족과 민족이 거주하기 때문에 동서남북에 따라 음식의 형태나 관념이 많이 다르다.     NaN
# 2              2    대개 쌀과 푸푸, 투오, 기기, 이튜, 아토 등으로 구성되며 대개는 소스와 수프이다.     NaN
# 3              3                    수프에는 달팽이, 생선, 고기, 버섯 등을 넣어 먹는다.     NaN
# 4              4                                  자주 먹는 음식은 다음과 같다.     NaN
# ...          ...                                                ...     ...
# 2629          43                       호텔 안의 프랑스 요리점은 프랑스 찬팅이라고 한다.     NaN
# 2630          44       맛도 좋고 실내 장식과 서비스도 세련되었으며 가격도 그리 비싸지 않은 가게이다.     NaN
# 2631          45              마이땅라오(맥도널드)나 KFC는 맛과 시스템이 대한민국과 비슷하다.     NaN
# 2632          46                            땨쟈러(大家樂)는 홍콩 자본의 체인점이다.     NaN
# 2633          47  면류나 덮밥 등의 중화 메뉴도 있는 패스트푸드점인 小食店은 오전5시부터 밤12시까지...     NaN
#
#      object  label memo
# 0       NaN    NaN  NaN
# ...
